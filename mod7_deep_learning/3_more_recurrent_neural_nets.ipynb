# %% [markdown]
# # Deep Learning: More Recurrent Neural Networks

# %% [markdown]
# ### installation + debugging stuff

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:14
# 🔁 Restarting kernel...

# %%
# !conda create --name myenv python=3.11
# !conda activate myenv
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.2
#     latest version: 26.3.2
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/myenv
#
#   added / updated specs:
#     - python=3.11
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |           20_gnu          28 KB  conda-forge
#     bzip2-1.0.8                |       hda65f42_9         254 KB  conda-forge
#     ca-certificates-2026.4.22  |       hbd8a1cb_0         128 KB  conda-forge
#     icu-78.3                   |       h33c6efd_0        12.1 MB  conda-forge
#     ld_impl_linux-64-2.45.1    |default_hbd61a6d_102         711 KB  conda-forge
#     libexpat-2.7.5             |       hecca717_0          75 KB  conda-forge
#     libffi-3.5.2               |       h3435931_0          57 KB  conda-forge
#     libgcc-15.2.0              |      he0feb66_18        1017 KB  conda-forge
#     libgcc-ng-15.2.0           |      h69a702a_18          27 KB  conda-forge
#     libgomp-15.2.0             |      he0feb66_18         589 KB  conda-forge
#     liblzma-5.8.3              |       hb03c661_0         111 KB  conda-forge
#     libnsl-2.0.1               |       hb9d3cd8_1          33 KB  conda-forge
#     libsqlite-3.53.0           |       hf4e2dac_0         936 KB  conda-forge
#     libstdcxx-15.2.0           |      h934c35e_18         5.6 MB  conda-forge
#     libuuid-2.42               |       h5347b49_0          39 KB  conda-forge
#     libzlib-1.3.2              |       h25fd6f3_2          62 KB  conda-forge
#     ncurses-6.5                |       h2d0b736_3         871 KB  conda-forge
#     openssl-3.6.2              |       h35e630c_0         3.0 MB  conda-forge
#     packaging-26.2             |     pyhc364b38_0          89 KB  conda-forge
#     pip-26.0.1                 |     pyh8b19718_0         1.1 MB  conda-forge
#     python-3.11.15             |hd63d673_0_cpython        29.5 MB  conda-forge
#     readline-8.3               |       h853b02a_0         337 KB  conda-forge
#     setuptools-82.0.1          |     pyh332efcf_0         625 KB  conda-forge
#     tk-8.6.13                  |noxft_h366c992_103         3.1 MB  conda-forge
#     tzdata-2025c               |       hc9c84f9_1         116 KB  conda-forge
#     wheel-0.47.0               |     pyhd8ed1ab_0          33 KB  conda-forge
#     zstd-1.5.7                 |       hb78ec9c_6         587 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        61.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-20_gnu
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-hda65f42_9
#   ca-certificates    conda-forge/noarch::ca-certificates-2026.4.22-hbd8a1cb_0
#   icu                conda-forge/linux-64::icu-78.3-h33c6efd_0
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.45.1-default_hbd61a6d_102
#   libexpat           conda-forge/linux-64::libexpat-2.7.5-hecca717_0
#   libffi             conda-forge/linux-64::libffi-3.5.2-h3435931_0
#   libgcc             conda-forge/linux-64::libgcc-15.2.0-he0feb66_18
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-15.2.0-h69a702a_18
#   libgomp            conda-forge/linux-64::libgomp-15.2.0-he0feb66_18
#   liblzma            conda-forge/linux-64::liblzma-5.8.3-hb03c661_0
#   libnsl             conda-forge/linux-64::libnsl-2.0.1-hb9d3cd8_1
#   libsqlite          conda-forge/linux-64::libsqlite-3.53.0-hf4e2dac_0
#   libstdcxx          conda-forge/linux-64::libstdcxx-15.2.0-h934c35e_18
#   libuuid            conda-forge/linux-64::libuuid-2.42-h5347b49_0
#   libxcrypt          conda-forge/linux-64::libxcrypt-4.4.36-hd590300_1
#   libzlib            conda-forge/linux-64::libzlib-1.3.2-h25fd6f3_2
#   ncurses            conda-forge/linux-64::ncurses-6.5-h2d0b736_3
#   openssl            conda-forge/linux-64::openssl-3.6.2-h35e630c_0
#   packaging          conda-forge/noarch::packaging-26.2-pyhc364b38_0
#   pip                conda-forge/noarch::pip-26.0.1-pyh8b19718_0
#   python             conda-forge/linux-64::python-3.11.15-hd63d673_0_cpython
#   readline           conda-forge/linux-64::readline-8.3-h853b02a_0
#   setuptools         conda-forge/noarch::setuptools-82.0.1-pyh332efcf_0
#   tk                 conda-forge/linux-64::tk-8.6.13-noxft_h366c992_103
#   tzdata             conda-forge/noarch::tzdata-2025c-hc9c84f9_1
#   wheel              conda-forge/noarch::wheel-0.47.0-pyhd8ed1ab_0
#   zstd               conda-forge/linux-64::zstd-1.5.7-hb78ec9c_6
#
#
#
# Downloading and Extracting Packages:
# python-3.11.15       | 29.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
# icu-78.3             | 12.1 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
# libstdcxx-15.2.0     | 5.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# tk-8.6.13            | 3.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# openssl-3.6.2        | 3.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# pip-26.0.1           | 1.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# libgcc-15.2.0        | 1017 KB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# libsqlite-3.53.0     | 936 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# ncurses-6.5          | 871 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 711 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# setuptools-82.0.1    | 625 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# libgomp-15.2.0       | 589 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.7           | 587 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# readline-8.3         | 337 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 254 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2026 | 128 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025c         | 116 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.3        | 111 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-26.2       | 89 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.11.15       | 29.5 MB   | :   1% 0.008470082331795468/1 [00:00<00:11, 11.87s/it]
# icu-78.3             | 12.1 MB   | :   7% 0.06696044964530457/1 [00:00<00:01,  1.50s/it]
#
# libstdcxx-15.2.0     | 5.6 MB    | :   6% 0.055991374375676015/1 [00:00<00:01,  1.80s/it]
#
#
# tk-8.6.13            | 3.1 MB    | :  36% 0.357339582381658/1 [00:00<00:00,  3.56it/s]
#
#
#
# python-3.11.15       | 29.5 MB   | :  12% 0.12069867322808543/1 [00:00<00:01,  1.45s/it]
# icu-78.3             | 12.1 MB   | :  36% 0.3605562673208707/1 [00:00<00:00,  1.99it/s]
#
# libstdcxx-15.2.0     | 5.6 MB    | :  76% 0.7642822602279776/1 [00:00<00:00,  4.37it/s]
#
#
# tk-8.6.13            | 3.1 MB    | : 100% 1.0/1 [00:00<00:00,  4.55it/s]
#
#
# tk-8.6.13            | 3.1 MB    | : 100% 1.0/1 [00:00<00:00,  4.55it/s]
#
#
#
#
# pip-26.0.1           | 1.1 MB    | :   1% 0.013863715211670432/1 [00:00<00:18, 18.87s/it]
#
#
#
# openssl-3.6.2        | 3.0 MB    | : 100% 1.0/1 [00:00<00:00,  4.08it/s]
#
#
#
# python-3.11.15       | 29.5 MB   | :  23% 0.22922160310421485/1 [00:00<00:00,  1.15s/it]
# icu-78.3             | 12.1 MB   | :  70% 0.7043724222304153/1 [00:00<00:00,  2.64it/s]
#
#
#
#
#
# libgcc-15.2.0        | 1017 KB   | :   2% 0.01572680814138769/1 [00:00<00:19, 20.26s/it]
#
#
#
#
# pip-26.0.1           | 1.1 MB    | : 100% 1.0/1 [00:00<00:00, 18.87s/it]
#
#
#
#
#
#
# libsqlite-3.53.0     | 936 KB    | :   2% 0.017086886148609187/1 [00:00<00:20, 21.10s/it]
#
#
#
#
#
# python-3.11.15       | 29.5 MB   | :  32% 0.3239806491911767/1 [00:00<00:00,  1.11s/it]
#
# libstdcxx-15.2.0     | 5.6 MB    | : 100% 1.0/1 [00:00<00:00,  4.37it/s]
#
#
#
#
#
#
# libsqlite-3.53.0     | 936 KB    | : 100% 1.0/1 [00:00<00:00, 21.10s/it]
# icu-78.3             | 12.1 MB   | :  97% 0.9683511179474814/1 [00:00<00:00,  2.33it/s]
#
#
#
#
#
#
#
# ncurses-6.5          | 871 KB    | :   2% 0.018375108367605347/1 [00:00<00:22, 23.01s/it]
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 711 KB    | :   2% 0.022505432677382753/1 [00:00<00:19, 19.82s/it]
#
#
#
#
#
#
#
#
#
# setuptools-82.0.1    | 625 KB    | :   3% 0.025612125740780402/1 [00:00<00:17, 17.50s/it]
#
#
#
#
#
#
#
#
#
# setuptools-82.0.1    | 625 KB    | : 100% 1.0/1 [00:00<00:00, 17.50s/it]
#
#
#
#
#
#
#
# python-3.11.15       | 29.5 MB   | :  41% 0.4139752739665035/1 [00:00<00:00,  1.19s/it]
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 711 KB    | : 100% 1.0/1 [00:00<00:00, 19.82s/it]
#
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.7           | 587 KB    | :   3% 0.027244231968405738/1 [00:00<00:18, 19.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# readline-8.3         | 337 KB    | :   5% 0.047479808620205/1 [00:00<00:10, 11.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# readline-8.3         | 337 KB    | : 100% 1.0/1 [00:00<00:00, 11.37s/it]
#
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.7           | 587 KB    | : 100% 1.0/1 [00:00<00:00, 19.28s/it]
#
#
#
#
#
#
#
#
#
#
# libgomp-15.2.0       | 589 KB    | :   3% 0.027159012170499718/1 [00:00<00:20, 20.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 254 KB    | :   6% 0.06297130470209315/1 [00:00<00:08,  9.45s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.11.15       | 29.5 MB   | :  53% 0.5267332450085307/1 [00:00<00:00,  1.07s/it]
#
#
#
#
#
#
#
#
#
#
# libgomp-15.2.0       | 589 KB    | : 100% 1.0/1 [00:00<00:00, 20.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2026 | 128 KB    | : 100% 1.0/1 [00:00<00:00,  4.78s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 254 KB    | : 100% 1.0/1 [00:00<00:00,  9.45s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025c         | 116 KB    | :  14% 0.13752465690183405/1 [00:00<00:04,  4.72s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025c         | 116 KB    | : 100% 1.0/1 [00:00<00:00,  4.72s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.3        | 111 KB    | :  14% 0.14438040853733763/1 [00:00<00:03,  4.56s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-26.2       | 89 KB     | :  18% 0.17891541267171904/1 [00:00<00:03,  3.71s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-26.2       | 89 KB     | : 100% 1.0/1 [00:00<00:00,  3.71s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.3        | 111 KB    | : 100% 1.0/1 [00:00<00:00,  4.56s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.11.15       | 29.5 MB   | :  63% 0.6304917535730252/1 [00:00<00:00,  1.04s/it]
# python-3.11.15       | 29.5 MB   | :  94% 0.9391203785378226/1 [00:00<00:00,  1.29it/s]
#
#
#
# python-3.11.15       | 29.5 MB   | : 100% 1.0/1 [00:01<00:00,  1.29it/s]
#
#
# tk-8.6.13            | 3.1 MB    | : 100% 1.0/1 [00:01<00:00,  4.55it/s]
#
#
#
#
#
# libgcc-15.2.0        | 1017 KB   | : 100% 1.0/1 [00:01<00:00,  1.43s/it]
#
#
#
#
#
# libgcc-15.2.0        | 1017 KB   | : 100% 1.0/1 [00:01<00:00,  1.43s/it]
#
#
#
#
# pip-26.0.1           | 1.1 MB    | : 100% 1.0/1 [00:01<00:00,  1.52s/it]
#
#
#
#
# pip-26.0.1           | 1.1 MB    | : 100% 1.0/1 [00:01<00:00,  1.52s/it]
#
#
#
#
#
#
# libsqlite-3.53.0     | 936 KB    | : 100% 1.0/1 [00:01<00:00,  1.53s/it]
#
#
#
#
#
#
# libsqlite-3.53.0     | 936 KB    | : 100% 1.0/1 [00:01<00:00,  1.53s/it]
#
# libstdcxx-15.2.0     | 5.6 MB    | : 100% 1.0/1 [00:01<00:00,  4.37it/s]
#
#
#
#
#
#
#
#
#
# setuptools-82.0.1    | 625 KB    | : 100% 1.0/1 [00:01<00:00,  1.85s/it]
#
#
#
#
#
#
#
#
#
# setuptools-82.0.1    | 625 KB    | : 100% 1.0/1 [00:01<00:00,  1.85s/it]
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 711 KB    | : 100% 1.0/1 [00:02<00:00,  1.92s/it]
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 711 KB    | : 100% 1.0/1 [00:02<00:00,  1.92s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# readline-8.3         | 337 KB    | : 100% 1.0/1 [00:02<00:00,  1.97s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# readline-8.3         | 337 KB    | : 100% 1.0/1 [00:02<00:00,  1.97s/it]
#
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.7           | 587 KB    | : 100% 1.0/1 [00:02<00:00,  2.02s/it]
#
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.7           | 587 KB    | : 100% 1.0/1 [00:02<00:00,  2.02s/it]
#
#
#
#
#
#
#
#
#
#
# libgomp-15.2.0       | 589 KB    | : 100% 1.0/1 [00:02<00:00,  2.10s/it]
#
#
#
#
#
#
#
#
#
#
# libgomp-15.2.0       | 589 KB    | : 100% 1.0/1 [00:02<00:00,  2.10s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2026 | 128 KB    | : 100% 1.0/1 [00:02<00:00,  2.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2026 | 128 KB    | : 100% 1.0/1 [00:02<00:00,  2.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 254 KB    | : 100% 1.0/1 [00:02<00:00,  2.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 254 KB    | : 100% 1.0/1 [00:02<00:00,  2.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025c         | 116 KB    | : 100% 1.0/1 [00:02<00:00,  2.75s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025c         | 116 KB    | : 100% 1.0/1 [00:02<00:00,  2.75s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-26.2       | 89 KB     | : 100% 1.0/1 [00:02<00:00,  2.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-26.2       | 89 KB     | : 100% 1.0/1 [00:02<00:00,  2.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.3        | 111 KB    | : 100% 1.0/1 [00:02<00:00,  2.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.3        | 111 KB    | : 100% 1.0/1 [00:02<00:00,  2.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
# ncurses-6.5          | 871 KB    | : 100% 1.0/1 [00:03<00:00,  3.85s/it]
#
#
#
#
#
#
#
# ncurses-6.5          | 871 KB    | : 100% 1.0/1 [00:03<00:00,  3.85s/it]
# python-3.11.15       | 29.5 MB   | : 100% 1.0/1 [00:05<00:00,  1.29it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate myenv
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
# CondaError: Run 'conda init' before 'conda activate'

# %%
# !conda init bash

# !conda run -n myenv pip install torch==2.1.2 torchvision==0.16.2 torchaudio==2.1.2 --index-url https://download.pytorch.org/whl/cu118
# !conda run -n myenv pip install torchtext==0.6.0
# Out:
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# no change     /usr/local/etc/fish/conf.d/conda.fish
# no change     /usr/local/shell/condabin/Conda.psm1
# no change     /usr/local/shell/condabin/conda-hook.ps1
# no change     /usr/local/lib/python3.11/site-packages/xontrib/conda.xsh
# no change     /usr/local/etc/profile.d/conda.csh
# no change     /root/.bashrc
# No action taken.
#
# CondaError: KeyboardInterrupt
#
# ^C
# ^C

# %%
import sys
print(f"Current Python version: {sys.version}")
# Out:
# Current Python version: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]

# %%
# !pip install torchtext==0.6.0
# Out:
# Collecting torchtext==0.6.0
#   Downloading torchtext-0.6.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/site-packages (from torchtext==0.6.0) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/site-packages (from torchtext==0.6.0) (2.32.3)
# Collecting torch (from torchtext==0.6.0)
#   Downloading torch-2.11.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting numpy (from torchtext==0.6.0)
#   Using cached numpy-2.4.4-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting six (from torchtext==0.6.0)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting sentencepiece (from torchtext==0.6.0)
#   Downloading sentencepiece-0.2.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests->torchtext==0.6.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests->torchtext==0.6.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests->torchtext==0.6.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests->torchtext==0.6.0) (2024.12.14)
# Collecting filelock (from torch->torchtext==0.6.0)
#   Using cached filelock-3.29.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting typing-extensions>=4.10.0 (from torch->torchtext==0.6.0)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.11/site-packages (from torch->torchtext==0.6.0) (65.6.3)
# Collecting sympy>=1.13.3 (from torch->torchtext==0.6.0)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch->torchtext==0.6.0)
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting jinja2 (from torch->torchtext==0.6.0)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=0.8.5 (from torch->torchtext==0.6.0)
#   Using cached fsspec-2026.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting cuda-toolkit==13.0.2 (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->torchtext==0.6.0)
#   Downloading cuda_toolkit-13.0.2-py2.py3-none-any.whl.metadata (9.4 kB)
# Collecting cuda-bindings<14,>=13.0.3 (from torch->torchtext==0.6.0)
#   Downloading cuda_bindings-13.2.0-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (2.3 kB)
# Collecting nvidia-cudnn-cu13==9.19.0.56 (from torch->torchtext==0.6.0)
#   Downloading nvidia_cudnn_cu13-9.19.0.56-py3-none-manylinux_2_27_x86_64.whl.metadata (1.9 kB)
# Collecting nvidia-cusparselt-cu13==0.8.0 (from torch->torchtext==0.6.0)
#   Downloading nvidia_cusparselt_cu13-0.8.0-py3-none-manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting nvidia-nccl-cu13==2.28.9 (from torch->torchtext==0.6.0)
#   Downloading nvidia_nccl_cu13-2.28.9-py3-none-manylinux_2_18_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvshmem-cu13==3.4.5 (from torch->torchtext==0.6.0)
#   Downloading nvidia_nvshmem_cu13-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting triton==3.6.0 (from torch->torchtext==0.6.0)
#   Downloading triton-3.6.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cublas==13.1.0.3.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->torchtext==0.6.0)
#   Downloading nvidia_cublas-13.1.0.3-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime==13.0.96.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->torchtext==0.6.0)
#   Downloading nvidia_cuda_runtime-13.0.96-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft==12.0.0.61.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->torchtext==0.6.0)
#   Downloading nvidia_cufft-12.0.0.61-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cufile==1.15.1.6.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->torchtext==0.6.0)
#   Downloading nvidia_cufile-1.15.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti==13.0.85.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->torchtext==0.6.0)
#   Downloading nvidia_cuda_cupti-13.0.85-py3-none-manylinux_2_25_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand==10.4.0.35.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->torchtext==0.6.0)
#   Downloading nvidia_curand-10.4.0.35-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver==12.0.4.66.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->torchtext==0.6.0)
#   Downloading nvidia_cusolver-12.0.4.66-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse==12.6.3.3.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->torchtext==0.6.0)
#   Downloading nvidia_cusparse-12.6.3.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink==13.0.88.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->torchtext==0.6.0)
#   Downloading nvidia_nvjitlink-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-nvrtc==13.0.88.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->torchtext==0.6.0)
#   Downloading nvidia_cuda_nvrtc-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvtx==13.0.85.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->torchtext==0.6.0)
#   Downloading nvidia_nvtx-13.0.85-py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl.metadata (1.8 kB)
# Collecting cuda-pathfinder~=1.1 (from cuda-bindings<14,>=13.0.3->torch->torchtext==0.6.0)
#   Downloading cuda_pathfinder-1.5.3-py3-none-any.whl.metadata (1.9 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch->torchtext==0.6.0)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch->torchtext==0.6.0)
#   Using cached markupsafe-3.0.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# Downloading torchtext-0.6.0-py3-none-any.whl (64 kB)
# Downloading numpy-2.4.4-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 48.2 MB/s eta 0:00:00
# Downloading sentencepiece-0.2.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 75.2 MB/s eta 0:00:00
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading torch-2.11.0-cp311-cp311-manylinux_2_28_x86_64.whl (530.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 530.6/530.6 MB 36.7 MB/s eta 0:00:00
# Downloading cuda_toolkit-13.0.2-py2.py3-none-any.whl (2.4 kB)
# Downloading nvidia_cudnn_cu13-9.19.0.56-py3-none-manylinux_2_27_x86_64.whl (366.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.1/366.1 MB 23.6 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu13-0.8.0-py3-none-manylinux2014_x86_64.whl (169.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.9/169.9 MB 17.7 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu13-2.28.9-py3-none-manylinux_2_18_x86_64.whl (196.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.5/196.5 MB 13.7 MB/s eta 0:00:00
# Downloading nvidia_nvshmem_cu13-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (60.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 MB 8.6 MB/s eta 0:00:00
# Downloading triton-3.6.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (188.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.2/188.2 MB 4.7 MB/s eta 0:00:00
# Downloading nvidia_cublas-13.1.0.3-py3-none-manylinux_2_27_x86_64.whl (423.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 MB 8.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti-13.0.85-py3-none-manylinux_2_25_x86_64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 16.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (90.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.2/90.2 MB 16.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime-13.0.96-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 17.7 MB/s eta 0:00:00
# Downloading nvidia_cufft-12.0.0.61-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (214.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.1/214.1 MB 11.1 MB/s eta 0:00:00
# Downloading nvidia_cufile-1.15.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 6.9 MB/s eta 0:00:00
# Downloading nvidia_curand-10.4.0.35-py3-none-manylinux_2_27_x86_64.whl (59.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver-12.0.4.66-py3-none-manylinux_2_27_x86_64.whl (200.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.9/200.9 MB 9.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse-12.6.3.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (145.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.9/145.9 MB 8.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (40.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_nvtx-13.0.85-py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (148 kB)
# Downloading cuda_bindings-13.2.0-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 8.9 MB/s eta 0:00:00
# Downloading fsspec-2026.3.0-py3-none-any.whl (202 kB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading filelock-3.29.0-py3-none-any.whl (39 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading cuda_pathfinder-1.5.3-py3-none-any.whl (49 kB)
# Downloading markupsafe-3.0.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (22 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: nvidia-cusparselt-cu13, mpmath, cuda-toolkit, typing-extensions, triton, sympy, six, sentencepiece, nvidia-nvtx, nvidia-nvshmem-cu13, nvidia-nvjitlink, nvidia-nccl-cu13, nvidia-curand, nvidia-cufile, nvidia-cuda-runtime, nvidia-cuda-nvrtc, nvidia-cuda-cupti, nvidia-cublas, numpy, networkx, MarkupSafe, fsspec, filelock, cuda-pathfinder, nvidia-cusparse, nvidia-cufft, nvidia-cudnn-cu13, jinja2, cuda-bindings, nvidia-cusolver, torch, torchtext
# ^C

# %%
# !pip uninstall -y torch torchtext

# !pip install torch==2.1.2 torchvision==0.16.2 torchaudio==2.1.2 --index-url https://download.pytorch.org/whl/cu118
# !pip install torchtext==0.16.2
# Out:
# WARNING: Skipping torch as it is not installed.
# WARNING: Skipping torchtext as it is not installed.
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Collecting torch==2.1.2
#   Using cached https://download-r2.pytorch.org/whl/cu118/torch-2.1.2%2Bcu118-cp311-cp311-linux_x86_64.whl (2325.9 MB)
# ERROR: Operation cancelled by user
# ^C

# %%
# !pip install torchtext==0.6.0

# %%
import torch
import torch.nn as nn
# !pip install torchtext==0.6.0
import torchtext
from torchtext.data import Field, LabelField, BucketIterator
from torchtext.datasets import SST
from tqdm import tqdm
import matplotlib.pyplot as plt
torch.manual_seed(12)

print(f"Pytorch version: {torch.__version__}")
print(f"Torchtext version: {torchtext.__version__}")
# Out:
# Collecting torchtext==0.6.0
#   Downloading torchtext-0.6.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torchtext==0.6.0) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torchtext==0.6.0) (2.32.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from torchtext==0.6.0) (2.6.0+cu124)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchtext==0.6.0) (2.0.2)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from torchtext==0.6.0) (1.17.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from torchtext==0.6.0) (0.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.6.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.6.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.6.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.6.0) (2025.7.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->torchtext==0.6.0) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->torchtext==0.6.0) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->torchtext==0.6.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->torchtext==0.6.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->torchtext==0.6.0) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->torchtext==0.6.0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->torchtext==0.6.0)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->torchtext==0.6.0)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->torchtext==0.6.0)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->torchtext==0.6.0)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->torchtext==0.6.0)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->torchtext==0.6.0)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->torchtext==0.6.0)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->torchtext==0.6.0)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->torchtext==0.6.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->torchtext==0.6.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->torchtext==0.6.0) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->torchtext==0.6.0)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->torchtext==0.6.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->torchtext==0.6.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->torchtext==0.6.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->torchtext==0.6.0) (3.0.2)
# Downloading torchtext-0.6.0-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 6.3 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 120.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 54.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 10.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 68.0 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torchtext
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 torchtext-0.6.0
# Pytorch version: 2.6.0+cu124
# Torchtext version: 0.6.0

# %% [markdown]
# ### Note: Python must be 3.11.x
#
# If your kernel shows a value > 3.11.x you will need to downgrade. Please email the staff for help

# %%
# DEVICE CONFIGURATION
if torch.backends.mps.is_available():          # Apple Silicon
    device = torch.device("mps")
elif torch.cuda.is_available():                # CUDA GPU
    device = torch.device("cuda")
else:
    device = torch.device("cpu")               # Fallback

print("Using device:", device)
# Out:
# Using device: cpu

# %%
# Define field types
TEXT = Field(tokenize='basic_english', lower=True, include_lengths=True)
LABEL = LabelField(dtype=torch.float)

# Load SST data
train_data, _, test_data = SST.splits(
    TEXT, LABEL, fine_grained=True
)
# Out:
# downloading trainDevTestTrees_PTB.zip
# trainDevTestTrees_PTB.zip: 100%|██████████| 790k/790k [00:02<00:00, 334kB/s]
# extracting

# %%
# Display size of datasets
print("Train size:", len(train_data))
print("Test size:", len(test_data))
# Out:
# Train size: 8544
# Test size: 2210

# %% [markdown]
# The `.splits` method is splitting up our dataset so that our train and test sets both have representative samples.
#
# The `fine_grained` parameter determines how many categories our data is broken into.
# - if `True`: labels can be {'positive': 0, 'negative': 1, 'neutral': 2, 'very positive': 3, 'very negative': 4}
# - if `False`: labels can be {'positive': 0, 'negative': 1, 'neutral': 2}

# %%
# Build vocabulary
MAX_VOCAB_SIZE = 10000
TEXT.build_vocab(train_data, max_size=MAX_VOCAB_SIZE)
LABEL.build_vocab(train_data)

vocab = TEXT.vocab.stoi
pad_idx = TEXT.vocab.stoi[TEXT.pad_token]

# %% [markdown]
# ### Q: What variable type is `vocab`? What does the `.build_vocab` method do?
# Hint: `.stoi` stand for "string to int"!

# %% [markdown]
# ### A:
# The variable `vocab` is a dictionary and `.build_vocab` creates a table with those tokens and integers.

# %%
def decode_dataset(dataset):
    # Reverse label mapping: string -> int
    label_stoi = LABEL.vocab.stoi
    texts = [example.text for example in dataset]
    labels = [label_stoi[example.label] for example in dataset]
    return texts, labels

train_texts, train_labels = decode_dataset(train_data)
test_texts, test_labels   = decode_dataset(test_data)

# %% [markdown]
# ### Sanity Check 🧠
# Let's check that the decoded dataset makes sense!

# %%
label_map = {idx: word for word, idx in LABEL.vocab.stoi.items()}

# Change i and see what happens!
i = 0

print(" ".join(test_texts[i]))
print(label_map[test_labels[i]])
# Out:
# effective but too-tepid biopic
# neutral

# %% [markdown]
# ----

# %% [markdown]
# Now let's define a `BucketIterator`:

# %%
BATCH_SIZE = 32
train_iterator, test_iterator = BucketIterator.splits(
    (train_data, test_data),
    batch_size=BATCH_SIZE,
    sort_within_batch=True,
    sort_key=lambda x: len(x.text),
    device=device
)

# %% [markdown]
# Below is a custom classifier:

# %%
# Custom LSTM Classifier
class SimpleLSTM(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim, pad_idx):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx=pad_idx)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=False)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, text, text_lengths):
        # text: [batch_size, seq_len] if batch_first=True
        embedded = self.embedding(text)  # [batch_size, seq_len, emb_dim]

        # Pack padded sequence
        packed_embedded = nn.utils.rnn.pack_padded_sequence(embedded, text_lengths.cpu(), batch_first=False, enforce_sorted=False)
        packed_output, (hidden, cell) = self.lstm(packed_embedded)

        # hidden: [1, batch_size, hidden_dim]  -> take the last hidden state
        return self.fc(hidden.squeeze(0))  # [batch_size, output_dim]

# %% [markdown]
# Here's a helper function so we can vary parameters later:

# %%
# TRAINING LOOP FUNCTION
def run_training_loop(num_epochs, random_state):
    # set random seed
    torch.manual_seed(random_state)

    EMBEDDING_DIM = 100
    HIDDEN_DIM = 256
    OUTPUT_DIM = 1

    # Send model to device
    model = SimpleLSTM(len(vocab), EMBEDDING_DIM, HIDDEN_DIM, OUTPUT_DIM, pad_idx).to(device)
    criterion = nn.BCEWithLogitsLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    # init output vars
    train_losses = []
    train_accs = []

    # train for num_epochs
    for epoch in range(num_epochs):
        model.train()
        epoch_loss = 0
        epoch_acc = 0

        # Wrap the iterator with tqdm
        for batch in tqdm(train_iterator, desc=f"Epoch {epoch+1}/{num_epochs}"):
            text, text_lengths = batch.text
            labels = batch.label

            text, text_lengths, labels = text.to(device), text_lengths.to(device), labels.to(device)

            optimizer.zero_grad()
            predictions = model(text, text_lengths).squeeze(1)

            # Loss
            loss = criterion(predictions, labels.float())
            loss.backward()
            optimizer.step()

            # Optional: compute accuracy
            preds = torch.round(torch.sigmoid(predictions))
            acc = (preds == labels).float().mean()
            epoch_loss += loss.item()
            epoch_acc += acc.item()

        avg_loss = epoch_loss/ len(train_iterator)
        avg_acc = epoch_acc/ len(train_iterator)
        train_losses.append(avg_loss)
        train_accs.append(avg_acc)
        print(f"Loss = {avg_loss:.4f}, Accuracy = {avg_acc:.4f}\n")
    return train_losses, train_accs, model

# %% [markdown]
# And another helper function plot the `train_losses` and `train_accs`:

# %%
def plot_training_performance(train_losses, train_accs, num_epochs, random_state):
    fig = plt.figure(figsize=(8,4), tight_layout=True)
    fig.suptitle(f"Model Training for State {random_state} over {num_epochs} Epochs")

    plt.subplot(1,2,1)
    plt.plot(train_losses, "-o", label="Train Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.grid()
    plt.legend()

    plt.subplot(1,2,2)
    plt.plot(train_accs, "-o", label="Train Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy (%)")
    plt.grid()
    plt.legend()
    plt.show()

# %% [markdown]
# Let's train our model!

# %%
NUM_EPOCHS = 15
RANDOM_STATE = 42
train_losses, train_accs, model = run_training_loop(NUM_EPOCHS, RANDOM_STATE)
# Out:
# Epoch 1/15: 100%|██████████| 267/267 [00:46<00:00,  5.68it/s]
# Loss = -24.7332, Accuracy = 0.2614
# Epoch 2/15: 100%|██████████| 267/267 [01:07<00:00,  3.96it/s]
# Loss = -65.5710, Accuracy = 0.2596
# Epoch 3/15: 100%|██████████| 267/267 [00:59<00:00,  4.47it/s]
# Loss = -104.8811, Accuracy = 0.2598
# Epoch 4/15: 100%|██████████| 267/267 [00:56<00:00,  4.72it/s]
# Loss = -143.8625, Accuracy = 0.2597
# Epoch 5/15: 100%|██████████| 267/267 [00:45<00:00,  5.86it/s]
# Loss = -182.6822, Accuracy = 0.2602
# Epoch 6/15: 100%|██████████| 267/267 [00:48<00:00,  5.51it/s]
# Loss = -221.7768, Accuracy = 0.2615
# Epoch 7/15: 100%|██████████| 267/267 [00:33<00:00,  7.88it/s]
# Loss = -260.5421, Accuracy = 0.2625
# Epoch 8/15: 100%|██████████| 267/267 [00:29<00:00,  8.93it/s]
# Loss = -298.4368, Accuracy = 0.2631
# Epoch 9/15: 100%|██████████| 267/267 [00:26<00:00, 10.14it/s]
# Loss = -334.7705, Accuracy = 0.2628
# Epoch 10/15: 100%|██████████| 267/267 [00:24<00:00, 10.97it/s]
# Loss = -375.6389, Accuracy = 0.2637
# Epoch 11/15: 100%|██████████| 267/267 [00:27<00:00,  9.64it/s]
# Loss = -415.9581, Accuracy = 0.2653
# Epoch 12/15: 100%|██████████| 267/267 [00:35<00:00,  7.62it/s]
# Loss = -455.7934, Accuracy = 0.2658
# Epoch 13/15: 100%|██████████| 267/267 [00:34<00:00,  7.65it/s]
# Loss = -495.5855, Accuracy = 0.2666
# Epoch 14/15: 100%|██████████| 267/267 [00:49<00:00,  5.44it/s]
# Loss = -535.6157, Accuracy = 0.2678
# Epoch 15/15: 100%|██████████| 267/267 [00:38<00:00,  6.85it/s]
# Loss = -575.2302, Accuracy = 0.2691

# %%
plot_training_performance(train_losses, train_accs, NUM_EPOCHS, RANDOM_STATE)

# %% [markdown]
# ### Q: Try changing the value of `NUM_EPOCHS`. What happens to the train loss and accuracy plots? What does this tell us about the optimal number of training epochs?

# %% [markdown]
# ### A:
# Increasing `NUM_EPOCHS` generally decreases the loss and increases the accuracy. So the optimal number of training epochs should result in loss decreasing and accuracy increasing up until the points at which they steady out.

# %% [markdown]
# ### Q: Try changing the value of `RANDOM_STATE`. What happens to the train loss and accuracy plots? What does this tell us about the impact of the initial guess (i.e. epoch 0)?

# %% [markdown]
# ### A:
# Changing `RANDOM_STATE` affects the y-intercepts of the plots. So the initial guess impacts the general shape of the plot and how it converges.

# %% [markdown]
# ----

# %% [markdown]
# ## Performance on the Test Set

# %% [markdown]
# Here's a helper function to run our model on the test data:

# %%
# Evaluate on test set
def run_evaluation_test():
    model.eval()
    test_loss, test_acc, = 0,0

    with torch.no_grad():
        for batch in test_iterator:
            text, text_lengths = batch.text
            labels = batch.label

            text = text.to(device)
            text_lengths = text_lengths.to(device)
            labels = labels.to(device)

            criterion = nn.BCEWithLogitsLoss()
            predictions = model(text, text_lengths).squeeze(1)
            loss = criterion(predictions, labels.float())

            preds = torch.round(torch.sigmoid(predictions))
            acc = (preds == labels).float().mean()

            test_loss += loss.item()
            test_acc += acc.item()

    return print(f"Test Accuracy: {100 * test_acc / len(test_iterator):.2f}%")

# %% [markdown]
# Finally, let's check that our model can generalize by processing the test data:

# %%
run_evaluation_test()
# Out:
# Test Accuracy: 28.26%

# %% [markdown]
# ----
# ## Further Exploration 🔎

# %% [markdown]
# ### Q: What happens to the **test** accuracy as `NUM_EPOCHS` is changed? What does this tell us about our neural network?
# Note: remember to re-train your model before running on the test set!

# %% [markdown]
# ### A:
# If `NUM_EPOCHS` is too low or too high, that could result in lower test accuracy, since either the model underfits and doesn't end up learning the patterns in the data, or it overfits and ends up essentially memorizing the training data.

# %% [markdown]
# ### Q: What happens to the **test** accuracy as `RANDOM_STATE` is changed? What does this tell us about our neural network?
# Note: remember to re-train your model before running on the test set!

# %% [markdown]
# ### A:
# Changing `RANDOM_STATE` results in slight variations in the accuracy depending on how stable the model is.

# %% [markdown]
# ### Q: What happens to your results if you set `find_grained=True`?
# Try to predict first and then test your hypothesis by changing the value and re-running the notebook!

# %% [markdown]
# ### A:
# With `fine_grained = True`, there are more categories and thus the model's results would end up being more detailed.
